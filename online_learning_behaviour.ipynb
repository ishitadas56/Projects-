# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier
df=pd.read_csv("C:\\Users\\Hp\\Downloads\\Impact of Covid 19 pandemic on medical education (1).csv")
df
# Out:
#      No.  Year Sex  Students who took standard English exams  \
# 0      1  2019   F                                         0
# 1      2  2019   M                                         0
# 2      3  2019   M                                         1
# 3      4  2019   F                                         1
# 4      5  2019   M                                         1
# ..   ...   ...  ..                                       ...
# 319  320  2021   M                                         1
# 320  321  2021   M                                         0
# 321  322  2021   M                                         0
# 322  323  2021   M                                         0
# 323  324  2021   M                                         1
#
#      English score in unicersity entrance exam  Reading skill (before course)  \
# 0                                        190.0                            3.0
# 1                                        187.2                            3.0
# 2                                        196.0                            4.0
# 3                                          NaN                            4.0
# 4                                        198.0                            5.0
# ..                                         ...                            ...
# 319                                      190.0                            1.0
# 320                                      180.0                            4.0
# 321                                      182.0                            3.0
# 322                                      178.0                            3.0
# 323                                      196.0                            2.0
#
#      Writing skill (before course)  Speaking skill (before course)  \
# 0                              3.0                             3.0
# 1                              3.0                             2.0
# 2                              3.0                             2.0
# 3                              4.0                             3.0
# 4                              3.0                             5.0
# ..                             ...                             ...
# 319                            1.0                             1.0
# 320                            4.0                             3.0
# 321                            3.0                             3.0
# 322                            1.0                             1.0
# 323                            2.0                             2.0
#
#      Listening skill (before course) Reading skill (after course)  \
# 0                                3.0                            3
# 1                                2.0                            3
# 2                                1.0                            4
# 3                                3.0                            3
# 4                                5.0                            5
# ..                               ...                          ...
# 319                              1.0                            3
# 320                              4.0                            4
# 321                              3.0                            3
# 322                              1.0                            3
# 323                              4.0                            3
#
#     Writing skill (after course)  Speaking skill (after course)  \
# 0                              3                            3.0
# 1                              3                            2.0
# 2                              4                            2.0
# 3                              3                            3.0
# 4                              3                            3.0
# ..                           ...                            ...
# 319                            4                            2.0
# 320                            4                            4.0
# 321                            3                            3.0
# 322                            2                            2.0
# 323                            2                            2.0
#
#      Listening skill (after course)  Medical terminoligy pre-test  \
# 0                               3.0                           7.0
# 1                               2.0                           NaN
# 2                               2.0                           6.0
# 3                               3.0                           5.0
# 4                               4.0                           8.0
# ..                              ...                           ...
# 319                             2.0                           1.0
# 320                             4.0                           8.0
# 321                             3.0                           5.0
# 322                             2.0                           9.0
# 323                             2.0                           6.0
#
#      Medical terminology post-test  Final written exam  Attendance  \
# 0                             10.0                  76          24
# 1                              9.0                  52          19
# 2                              7.0                  72          22
# 3                              9.0                  80          22
# 4                              9.0                  80          22
# ..                             ...                 ...         ...
# 319                           10.0                  48          15
# 320                           10.0                  92          24
# 321                            NaN                  92          25
# 322                           10.0                  80          25
# 323                           10.0                  80          22
#
#      Evidence-based medicine score  Total final score
# 0                             10.0               84.6
# 1                             10.0               65.2
# 2                             10.0               80.2
# 3                              9.0               83.5
# 4                              9.0               83.5
# ..                             ...                ...
# 319                           10.0               64.0
# 320                           10.0               95.0
# 321                           10.0               91.0
# 322                           10.0               90.0
# 323                           10.0               87.0
#
# [324 rows x 19 columns]

# %%
df.head()
# Out:
#    No.  Year Sex  Students who took standard English exams  \
# 0    1  2019   F                                         0
# 1    2  2019   M                                         0
# 2    3  2019   M                                         1
# 3    4  2019   F                                         1
# 4    5  2019   M                                         1
#
#    English score in unicersity entrance exam  Reading skill (before course)  \
# 0                                      190.0                            3.0
# 1                                      187.2                            3.0
# 2                                      196.0                            4.0
# 3                                        NaN                            4.0
# 4                                      198.0                            5.0
#
#    Writing skill (before course)  Speaking skill (before course)  \
# 0                            3.0                             3.0
# 1                            3.0                             2.0
# 2                            3.0                             2.0
# 3                            4.0                             3.0
# 4                            3.0                             5.0
#
#    Listening skill (before course) Reading skill (after course)  \
# 0                              3.0                            3
# 1                              2.0                            3
# 2                              1.0                            4
# 3                              3.0                            3
# 4                              5.0                            5
#
#   Writing skill (after course)  Speaking skill (after course)  \
# 0                            3                            3.0
# 1                            3                            2.0
# 2                            4                            2.0
# 3                            3                            3.0
# 4                            3                            3.0
#
#    Listening skill (after course)  Medical terminoligy pre-test  \
# 0                             3.0                           7.0
# 1                             2.0                           NaN
# 2                             2.0                           6.0
# 3                             3.0                           5.0
# 4                             4.0                           8.0
#
#    Medical terminology post-test  Final written exam  Attendance  \
# 0                           10.0                  76          24
# 1                            9.0                  52          19
# 2                            7.0                  72          22
# 3                            9.0                  80          22
# 4                            9.0                  80          22
#
#    Evidence-based medicine score  Total final score
# 0                           10.0               84.6
# 1                           10.0               65.2
# 2                           10.0               80.2
# 3                            9.0               83.5
# 4                            9.0               83.5

# %%
x=df.drop('Total final score',axis=1)
y=df['Total final score']
print("shape of x",x.shape)
print("shape of y",y.shape)
# Out:
# shape of x (324, 18)
# shape of y (324,)

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=51)

# %%
x_train
# Out:
#      No.  Year Sex  Students who took standard English exams  \
# 170  171  2020   M                                         0
# 18    19  2019   F                                         0
# 287  288  2021   M                                         0
# 217  218  2021   M                                         0
# 310  311  2021   F                                         0
# ..   ...   ...  ..                                       ...
# 222  223  2021   M                                         0
# 16    17  2019   M                                         0
# 197  198  2020   M                                         0
# 224  225  2021   M                                         0
# 57    58  2019   M                                         0
#
#      English score in unicersity entrance exam  Reading skill (before course)  \
# 170                                      182.0                            2.0
# 18                                       181.0                            3.0
# 287                                      172.0                            4.0
# 217                                      191.0                            4.0
# 310                                      185.0                            3.0
# ..                                         ...                            ...
# 222                                      186.0                            4.0
# 16                                       186.0                            2.0
# 197                                      192.0                            3.0
# 224                                      180.0                            4.0
# 57                                       180.0                            3.0
#
#      Writing skill (before course)  Speaking skill (before course)  \
# 170                            2.0                             1.0
# 18                             3.0                             2.0
# 287                            2.0                             3.0
# 217                            3.0                             2.0
# 310                            1.0                             2.0
# ..                             ...                             ...
# 222                            4.0                             2.0
# 16                             3.0                             2.0
# 197                            2.0                             1.0
# 224                            3.0                             1.0
# 57                             3.0                             3.0
#
#      Listening skill (before course) Reading skill (after course)  \
# 170                              2.0                            4
# 18                               3.0                            3
# 287                              3.0                            4
# 217                              3.0                            3
# 310                              3.0                            3
# ..                               ...                          ...
# 222                              3.0                            5
# 16                               2.0                            3
# 197                              2.0                            3
# 224                              2.0                            4
# 57                               3.0                            4
#
#     Writing skill (after course)  Speaking skill (after course)  \
# 170                            2                            1.0
# 18                             3                            3.0
# 287                            4                            4.0
# 217                            3                            3.0
# 310                            2                            2.0
# ..                           ...                            ...
# 222                            4                            4.0
# 16                             3                            3.0
# 197                            4                            2.0
# 224                            3                            2.0
# 57                             4                            3.0
#
#      Listening skill (after course)  Medical terminoligy pre-test  \
# 170                             2.0                           5.0
# 18                              3.0                           5.0
# 287                             4.0                           3.0
# 217                             3.0                           7.0
# 310                             3.0                           3.0
# ..                              ...                           ...
# 222                             5.0                           5.0
# 16                              3.0                           4.0
# 197                             2.0                           5.0
# 224                             2.0                           3.0
# 57                              4.0                           7.0
#
#      Medical terminology post-test  Final written exam  Attendance  \
# 170                            9.0                  78          23
# 18                             8.0                  76          25
# 287                            8.0                  92          25
# 217                           10.0                  72          25
# 310                           10.0                  84          25
# ..                             ...                 ...         ...
# 222                            9.0                  96          16
# 16                             9.0                  84          25
# 197                            8.0                  88          25
# 224                            NaN                  84          25
# 57                             9.0                  84          22
#
#      Evidence-based medicine score
# 170                           10.0
# 18                            10.0
# 287                           10.0
# 217                           10.0
# 310                            9.0
# ..                             ...
# 222                           10.0
# 16                             9.0
# 197                            8.0
# 224                            5.0
# 57                             8.0
#
# [259 rows x 18 columns]

# %%
y_train
# Out:
# 170    79.50
# 18     85.60
# 287    94.00
# 217    86.00
# 310    91.00
#        ...
# 222    88.00
# 16     88.90
# 197    88.25
# 224    80.00
# 57     84.40
# Name: Total final score, Length: 259, dtype: float64

# %%
print("Training data",x_train)
print("Testing data",x_test)
print("Training data",y_train)
print("Testing data",y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("Training data",x_train)
#       2 print("Testing data",x_test)
#       3 print("Training data",y_train)
#
# NameError: name 'x_train' is not defined

# %%
classifier=RandomForestClassifier()
classifier.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20868\3636917660.py in ?()
#       1 classifier=RandomForestClassifier()
# ----> 2 classifier.fit(x_train, y_train)
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     344         """
#     345         # Validate or convert input data
#     346         if issparse(y):
#     347             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348         X, y = self._validate_data(
#     349             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350         )
#     351         if sample_weight is not None:
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     617                 if "estimator" not in check_y_params:
#     618                     check_y_params = {**default_check_params, **check_y_params}
#     619                 y = check_array(y, input_name="y", **check_y_params)
#     620             else:
# --> 621                 X, y = check_X_y(X, y, **check_params)
#     622             out = X, y
#     623
#     624         if not no_val_X and check_params.get("ensure_2d", True):
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1143         raise ValueError(
#    1144             f"{estimator_name} requires y to be passed, but the target y is None"
#    1145         )
#    1146
# -> 1147     X = check_array(
#    1148         X,
#    1149         accept_sparse=accept_sparse,
#    1150         accept_large_sparse=accept_large_sparse,
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'M'

# %%
  
    
    
    
    
    
    
    ......
